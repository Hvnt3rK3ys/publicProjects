# %% [markdown]
# # First steps using Jupyter Notebooks
#
# ## Introduction
#
# This notebook provides an overview of various data science tools, languages, and libraries. It includes exercises to demonstrate basic arithmetic operations and conversions.
#
# ## Data Science Languages
#
# 1. Python
# 2. R
# 3. Julia
# 4. SQL
# 5. Scala
# 6. Java
# 7. JavaScript
# 8. MATLAB
# 9. SAS
# 10. Ruby
#
# ## Data Science Libraries
#
# 1. **Python Libraries:**
#    - NumPy
#    - Pandas
#    - SciPy
#    - Matplotlib
#    - Seaborn
#    - Scikit-learn
#    - TensorFlow
#    - Keras
#    - PyTorch
#
# 2. **R Libraries:**
#    - dplyr
#    - ggplot2
#    - caret
#    - randomForest
#    - shiny
#
# 3. **Julia Libraries:**
#    - DataFrames.jl
#    - Plots.jl
#    - Flux.jl
#    - Distributions.jl
#
#
# ## Data Science Tools
#
# | Category                                | Tools                                                                 |
# |-----------------------------------------|-----------------------------------------------------------------------|
# | **Open-Source Data Management Tools**   | MySQL, PostgreSQL, MongoDB, Apache CouchDB, Apache Cassandra, Hadoop File System, Ceph, Elastic Search |
# | **Data Integration and Transformation** | Apache AirFlow, KubeFlow, Apache Kafka, Apache Nifi, Apache SparkSQL, NodeRED |
# | **Data Visualization Tools**           | Pixie Dust, Hue, Kibana, Apache Superset                             |
# | **Model Deployment Tools**              | Apache PredictionIO, Seldon, MLeap, TensorFlow Service               |
# | **Model Monitoring Tools**              | ModelDB, Prometheus, IBM AI Fairness 360, IBM Adversarial Robustness 360 Toolbox, IBM AI Explainability 360 |
# | **Code Asset Management Tools**         | Git, GitHub, GitLab, Bitbucket                                        |
# | **Data Asset Management Tools**         | Apache Atlas, ODPi Egeria, Kylo                                      |
# | **Development Environments**            | Jupyter, Apache Zeppelin, RStudio, Spyder                              |
# | **Cluster Execution Environments**      | Apache Spark, Apache Flink, Ray                                      |
# | **Visual and Integrated Tools**         | KNIME, Orange                                                        |
#
#
# ## Arithmetic Expression Examples
#
# Below are some examples of basic arithmetic expressions in Python.
#
#
#
# ```python
# # Multiplication and Addition
# a = 10
# b = 5
# ```

# %%
# %%time
# Multiply
a=10
b=5
multiplication_result = a * b
print(f"Multiplication Result: {multiplication_result}")
# Out:
# Multiplication Result: 50
# CPU times: user 173 µs, sys: 0 ns, total: 173 µs
# Wall time: 192 µs

# %%
# %%time
# Add
a=2
b=5
addition_result = a + b
print(f"Addition Result: {addition_result}")
# Out:
# Addition Result: 7
# CPU times: user 71 µs, sys: 22 µs, total: 93 µs
# Wall time: 97.3 µs

# %%
# %%time
# Convert minutes to hours
minutes = 120
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 120 minutes is equal to 2.0 hours
# CPU times: user 162 µs, sys: 50 µs, total: 212 µs
# Wall time: 184 µs

# %% [markdown]
# ## Objectives
#
# 1. Understand the various data science languages and libraries.
# 2. Learn about different data science tools and their categories.
# 3. Perform basic arithmetic operations using Python.
# 4. Convert minutes to hours using Python.
#
# ## Author
#
# Manuel Parra
